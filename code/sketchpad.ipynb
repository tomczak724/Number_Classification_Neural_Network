# %%
#import DigitCanvas
#import matplotlib
#from matplotlib import pyplot
#%matplotlib notebook

#dc = DigitCanvas.DigitCanvas()
#dc.load_neural_network('../output/neural_network_28x28.json')
#pyplot.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
from bokeh.plotting import figure 
from bokeh.io import output_notebook, show

output_notebook()

from numpy import cos, linspace
x = linspace(-6, 6, 100)
y = cos(x)

p = figure(width=500, height=500)
p.circle(x, y, size=7, color="firebrick", alpha=0.5)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6e95f668-f13a-4f39-aa36-b11c598f0f06">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="a52b6f05-4903-4ec7-9619-c3b43605edb9"></div>
# </div>
